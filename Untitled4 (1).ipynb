# %%
#asssign 1
import random
list=[]
r=int(input("enter the size: "))
for i in range(r):
    a=random.randint(1,10)
    list.append(a)
print(list)
even=[]
odd=[]
prime=[]
r=int(input("enter the size: "))
for i in range(r):
    if(i%2==0):
        even.append(i)
    else:
        odd.append(i)
print(even)
print(odd)
for i in range(21):
    count=0
    if i>2:
        for j in range(2,i):
            if(i%j==0):
                count+=1
    if count==0:
        prime.append(i)
print(prime)
# Out:
# enter the size:  4
# [5, 4, 8, 5]
# enter the size:  10
# [0, 2, 4, 6, 8]
# [1, 3, 5, 7, 9]
# [0, 1, 2, 3, 5, 7, 11, 13, 17, 19]

# %%
#assign 5
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# #from sklearn.preprocessing import LabelEncoder
# df=pd.read_csv("Iris.csv")
# df.columns
# df.isna().sum().sum()#to check null value
# from sklearn.preprocessing import LabelEncoder
# l=LabelEncoder()
# l.fit_transform(df['Species'])#categorical to numerical

# %%
#assign 7
#assign 7
marks=np.random.randint(1,200,100)
marks
rf=pd.DataFrame({'marks':marks})
rf
fix,axes=plt.subplots(1,2,figsize=(10,8))
sns.distplot(rf['marks'],ax=axes[0])
sns.distplot(np.log(rf['marks']),ax=axes[1])#non linear
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14696\1972456666.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rf['marks'],ax=axes[0])
# C:\Users\hp\AppData\Local\Temp\ipykernel_14696\1972456666.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#histogram and barplot#assign8
plt.boxplot([df['Glucose'],df['BMI']])#{bar plot}
fig,axes=plt.subplots(2,2,figsize=(10,8))
axes[0][0].hist(df['BMI'])

# %%
#assign 9
sns.pairplot(df)
plt.plot(df[col1],df[col2])#line plot
plt.bar(df['Age'],df['BMI'])#barplot
sns.kdeplot(df['BMI'],fill=True)#density
with_p_d=df[(df['Pregnancies']!=0)&(df['Outcome']==1)]
witho_p_d=df[(df['Pregnancies']!=0)&(df['Outcome']==0)]
plt.pie([with_p_d.shape[0],witho_p_d.shape[0]]) #piechart
plt.scatter(df['Age'],df['BMI'],s=df['SkinThickness'],c=df['Glucose'])#scatter
plt.xlabel("hari")
plt.ylabel("soham")
plt.imshow(df.corr())
plt.colorbar()#heatmap
df.corr()#correlation matrix
z=linkage(df,data='ward')
dendeogram(z)
plt.show()
